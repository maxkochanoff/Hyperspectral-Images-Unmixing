# %%
from src.data_processing import HyperspectralImage, OriginalImageDataset
from torch.utils.data import DataLoader
from src.models import Autoencoder
from src.train_utils import train_model
from src.conf import BATCH_SIZE
from src.loss_functions import sad_loss
from src.metrics import compare_abundances, compare_endmembers
import matplotlib.pyplot as plt
import torch

# %%
samson = HyperspectralImage(image_path="datasets/samson/samson_1.mat",
                           ground_truth_path="datasets/samson/end3.mat",
                           n_bands=156, n_row=95, n_col=95, n_sources=3)

plt.imshow(samson.X[0])
plt.show()

original_image_dataset = OriginalImageDataset(hsi=samson, with_patches=True)
print(original_image_dataset.X.shape)
plt.imshow(original_image_dataset.X[0][0])
plt.show()



original_image_dataloader = DataLoader(dataset=original_image_dataset, batch_size=BATCH_SIZE, shuffle=True)
a = next(iter(original_image_dataloader))
print('original_image_dataloader', a["X"].shape)
plt.imshow(a['X'][0][0])
plt.show()
# Out:
# (100, 156, 40, 40)
# original_image_dataloader torch.Size([10, 156, 40, 40])

# %%
model = Autoencoder(channel_number=samson.n_bands, source_number=samson.n_sources)
model, loss_train = train_model(model, samson.X,
                                      original_image_dataloader,
                                      sad_loss, num_epochs=200, n_sources=3, need_plot=True)
# Out:
# TRAINING WILL BE DONE ON cpu
#  Epoch 1/200
# ----------------------------------------
# Learning rate: 0.01
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  3.03it/s]
# Loss: 2.0749
#  Epoch 2/200
# ----------------------------------------
# Learning rate: 0.01
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.99it/s]
# Loss: 0.2669
#  Epoch 3/200
# ----------------------------------------
# Learning rate: 0.01
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.96it/s]
# Loss: 0.2070
#  Epoch 4/200
# ----------------------------------------
# Learning rate: 0.01
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.90it/s]
# Loss: 0.2060
#  Epoch 5/200
# ----------------------------------------
# Learning rate: 0.01
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.88it/s]
# Loss: 0.1634
#  Epoch 6/200
# ----------------------------------------
# ...

# %%
plt.plot(loss_train)

# %%
torch.save(model.state_dict(), "results/models_weights/8_samson_original_patches.pth")

# %%
X, A, S = model(torch.Tensor(samson.X[None, :, :, :]))
X, A, S = X.detach().numpy()[0], A.detach().numpy(), S.detach().numpy()[0]
# Endmembers normalization
for i in range(A.shape[1]):
        M = A[:, i].max().item()
        A[:, i] = A[:, i]/M
                      
print('compare_endmembers', compare_endmembers(samson, A))
plt.figure(figsize=(8,3))
for ii in range(3): 
    ax = plt.subplot(1, 3, ii+1)
    ax.plot(A[:,ii])
plt.show()
                
print('compare_abundances', compare_abundances(samson, S))
plt.figure(figsize=(8,6))
for ii in range(3): 
    ax = plt.subplot(1, 3, ii+1)
    ax.imshow(S[ii, :, :])  
plt.show()
# Out:
# compare_endmembers 0.0019206504212107786
# compare_abundances 0.040486100555264255

# %%
np.save('results/first_estimation/samson_X_1_estim.npy', X)
np.save('results/first_estimation/samson_A_1_estim.npy', A)
np.save('results/first_estimation/samson_S_1_estim.npy', S)

# %%
plt.plot(endmembers_samson[:, 2])

# %%
abundances_samson = samson.S_gt # Here A is a dumb variable, don't pay attention to it. The abundances are S^*.
endmembers_samson = samson.A_gt

plt.figure(figsize = (10,8))
#TO DO : try to interpret the abundances that you see. Hint : the 3 sources are usually called ['Grass','Road','Rooftop (2)','Dirt','Trees','Rooftop (1)']. Associate a name to each endmember.
for ii in range(3): 
    ax = plt.subplot(2, 3, ii+1)
    ax.imshow(abundances_samson[ii,:].reshape(95,95))
    
    #plt.title(names[ii])
plt.figure(figsize = (10,5)),plt.plot(endmembers_samson)
plt.xlabel('channels');
