# %%
from src.data_processing import HyperspectralImage, PerturbedSVDataRandomPatches
from torch.utils.data import DataLoader
from src.models import Autoencoder
from src.train_utils import train_model
from src.conf import BATCH_SIZE
from src.loss_functions import balance_loss
import matplotlib.pyplot as plt
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
urban = HyperspectralImage(image_path="datasets/urban/Urban.mat",
                           ground_truth_path="datasets/urban/end6_groundTruth.mat",
                           n_bands=162, n_row=307, n_col=307, n_sources=6)

X_1_estim = np.load('results/first_estimation/X_1_estim.npy')
A_1_estim = np.load('results/first_estimation/A_1_estim.npy')
S_1_estim = np.load('results/first_estimation/S_1_estim.npy')

plt.imshow(urban.X[0])
plt.show()

sv_random_perturbed_image_dataset = PerturbedSVDataRandomPatches(urban, A_1_estim, S_1_estim)


sv_random_perturbed_image_dataloader = DataLoader(dataset=sv_random_perturbed_image_dataset, batch_size=BATCH_SIZE, shuffle=True)
a = next(iter(sv_random_perturbed_image_dataloader))
print('original_image_dataloader', a["X"].shape)
plt.imshow(a['X'][0][0])
plt.show()
# Out:
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
# original_image_dataloader torch.Size([10, 162, 40, 40])

# %%
model = Autoencoder(channel_number=urban.n_bands, source_number=urban.n_sources)
model, loss_train = train_model(model, urban.X,
                                sv_random_perturbed_image_dataloader,
                                balance_loss, num_epochs=50, n_sources=6, need_plot=True)
# Out:
# TRAINING WILL BE DONE ON cpu
#  Epoch 1/50
# ----------------------------------------
# Learning rate: 0.01
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   5%|██▏                                         | 1/20 [00:06<02:10,  6.87s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  10%|████▍                                       | 2/20 [00:13<02:02,  6.82s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  15%|██████▌                                     | 3/20 [00:20<01:55,  6.82s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  20%|████████▊                                   | 4/20 [00:27<01:49,  6.84s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  25%|███████████                                 | 5/20 [00:34<01:42,  6.82s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  30%|█████████████▏                              | 6/20 [00:40<01:35,  6.83s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  35%|███████████████▍                            | 7/20 [00:47<01:28,  6.82s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  40%|█████████████████▌                          | 8/20 [00:54<01:21,  6.82s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  45%|███████████████████▊                        | 9/20 [01:01<01:15,  6.84s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  50%|█████████████████████▌                     | 10/20 [01:08<01:08,  6.86s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  55%|███████████████████████▋                   | 11/20 [01:15<01:01,  6.84s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  60%|█████████████████████████▊                 | 12/20 [01:22<00:54,  6.84s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  65%|███████████████████████████▉               | 13/20 [01:28<00:47,  6.84s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  70%|██████████████████████████████             | 14/20 [01:35<00:40,  6.83s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  75%|████████████████████████████████▎          | 15/20 [01:42<00:34,  6.84s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  80%|██████████████████████████████████▍        | 16/20 [01:49<00:27,  6.84s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  85%|████████████████████████████████████▌      | 17/20 [01:56<00:20,  6.84s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  90%|██████████████████████████████████████▋    | 18/20 [02:03<00:13,  6.83s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  95%|████████████████████████████████████████▊  | 19/20 [02:09<00:06,  6.83s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 20/20 [02:16<00:00,  6.84s/it]
# Loss: 1.6606
#  Epoch 2/50
# ----------------------------------------
# Learning rate: 0.01
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   5%|██▏                                         | 1/20 [00:06<02:10,  6.86s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  10%|████▍                                       | 2/20 [00:13<02:02,  6.83s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  15%|██████▌                                     | 3/20 [00:20<01:55,  6.81s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  20%|████████▊                                   | 4/20 [00:27<01:49,  6.86s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  25%|███████████                                 | 5/20 [00:34<01:42,  6.86s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  30%|█████████████▏                              | 6/20 [00:41<01:36,  6.86s/it]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#   0%|          | 0/1600 [00:00<?, ?it/s]
#  30%|█████████████▏                              | 6/20 [00:44<01:43,  7.38s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in get(self, obj, cls)
#     536         try:
# --> 537             value = obj._trait_values[self.name]
#     538         except KeyError:
#
# KeyError: 'style'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/q0/m8_cyqvx79g68t6fgn385tm40000gn/T/ipykernel_43192/430388576.py in <module>
#       1 model = Autoencoder(channel_number=urban.n_bands, source_number=urban.n_sources)
# ----> 2 model, loss_train = train_model(model, urban.X,
#       3                                 sv_random_perturbed_image_dataloader,
#       4                                 balance_loss, num_epochs=50, n_sources=6, need_plot=True)
#
# ~/Desktop/Учеба/Telecom/PRIM/src/train_utils.py in train_model(model, hsi_data, dataloader, loss, num_epochs, n_sources, need_plot)
#      24         running_loss = 0
#      25
# ---> 26         for batch in tqdm(dataloader):
#      27             inputs_X = batch['X']
#      28
#
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1178
#    1179         try:
# -> 1180             for obj in iterable:
#    1181                 yield obj
#    1182                 # Update and possibly print the progressbar.
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     632                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633                 self._reset()  # type: ignore[call-arg]
# --> 634             data = self._next_data()
#     635             self._num_yielded += 1
#     636             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     676     def _next_data(self):
#     677         index = self._next_index()  # may raise StopIteration
# --> 678         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679         if self._pin_memory:
#     680             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# ~/Desktop/Учеба/Telecom/PRIM/src/data_processing.py in __getitem__(self, idx)
#     327     def __getitem__(self, idx):
#     328         X_patch, A, S_patch = _extract_random_patch(self.X, self.A, self.S)
# --> 329         sv_X_reshaped, sv_A_mean, sv_S_reshaped = _generate_sv_data(self.hsi, X_patch, A, S_patch, need_A_mean=True)
#     330
#     331         return {
#
# ~/Desktop/Учеба/Telecom/PRIM/src/data_processing.py in _generate_sv_data(hsi, X, endmembers_1_estim, abundances_1_estim, need_A_mean)
#     154     sv_X, sv_A_array, sv_S = np.zeros(X_pert.shape), [], np.zeros(S_pert.shape)
#     155
# --> 156     for k in tqdm(range(X.shape[1])):
#     157         sv_X_k, sv_A, sv_S_k = _spectral_variability_model(k, X_pert, A_pert, S_pert)
#     158         sv_X[:, k] = sv_X_k
#
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     240         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241         total = self.total * unit_scale if self.total else self.total
# --> 242         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243         self.container.pbar = proxy(self)
#     244         self.displayed = False
#
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     126                 pbar.layout.width = "20px"
#     127
# --> 128         ltext = HTML()
#     129         rtext = HTML()
#     130         if desc:
#
# /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget_string.py in __init__(self, value, **kwargs)
#      30         if value is not None:
#      31             kwargs['value'] = value
# ---> 32         super(_String, self).__init__(**kwargs)
#      33
#      34     _model_name = Unicode('StringModel').tag(sync=True)
#
# /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
# --> 415         self.open()
#     416
#     417     def __del__(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in open(self)
#     426         """Open a comm to the frontend if one isn't already open."""
#     427         if self.comm is None:
# --> 428             state, buffer_paths, buffers = _remove_buffers(self.get_state())
#     429
#     430             args = dict(target_name='jupyter.widget',
#
# /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in get_state(self, key, drop_defaults)
#     516         for k in keys:
#     517             to_json = self.trait_metadata(k, 'to_json', self._trait_to_json)
# --> 518             value = to_json(getattr(self, k), self)
#     519             if not PY3 and isinstance(traits[k], Bytes) and isinstance(value, bytes):
#     520                 value = memoryview(value)
#
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in __get__(self, obj, cls)
#     575             return self
#     576         else:
# --> 577             return self.get(obj, cls)
#     578
#     579     def set(self, obj, value):
#
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in get(self, obj, cls)
#     538         except KeyError:
#     539             # Check for a dynamic initializer.
# --> 540             default = obj.trait_defaults(self.name)
#     541             if default is Undefined:
#     542                 warn(
#
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in trait_defaults(self, *names, **metadata)
#    1578
#    1579         if len(names) == 1 and len(metadata) == 0:
# -> 1580             return self._get_trait_default_generator(names[0])(self)
#    1581
#    1582         trait_names = self.trait_names(**metadata)
#
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in default(self, obj)
#     511             return self.default_value
#     512         elif hasattr(self, 'make_dynamic_default'):
# --> 513             return self.make_dynamic_default()
#     514         else:
#     515             # Undefined will raise in TraitType.get
#
# /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/trait_types.py in make_dynamic_default(self)
#     166
#     167     def make_dynamic_default(self):
# --> 168         return self.klass(*(self.default_args or ()),
#     169                           **(self.default_kwargs or {}))
#     170
#
# /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
# --> 415         self.open()
#     416
#     417     def __del__(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in open(self)
#     436                 args['comm_id'] = self._model_id
#     437
# --> 438             self.comm = Comm(**args)
#     439
#     440     @observe('comm')
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/comm/comm.py in __init__(self, target_name, data, metadata, buffers, **kwargs)
#      51         if target_name:
#      52             kwargs['target_name'] = target_name
# ---> 53         super(Comm, self).__init__(**kwargs)
#      54         if self.kernel:
#      55             if self.primary:
#
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/config/configurable.py in __init__(self, **kwargs)
#     108         else:
#     109             # allow _config_default to return something
# --> 110             self._load_config(self.config)
#     111         self.unobserve(notice_config_override)
#     112
#
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/config/configurable.py in _load_config(self, cfg, section_names, traits)
#     155
#     156         if traits is None:
# --> 157             traits = self.traits(config=True)
#     158         if section_names is None:
#     159             section_names = self.section_names()
#
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in traits(self, **metadata)
#    1606         to the function.
#    1607         """
# -> 1608         traits = dict([memb for memb in getmembers(self.__class__) if
#    1609                      isinstance(memb[1], TraitType)])
#    1610
#
# /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in getmembers(object, predicate)
#     233             if not predicate or predicate(value):
#     234                 results.append((key, value))
# --> 235     results.sort()
#     236     return results
#     237
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), "results/models_weights/urban_sv_perturbed_no_patches.pth")

X, A, S = model(torch.Tensor(urban.data[None, :, :, :])
X, A, S = X.detach().numpy()[0], A.detach().numpy(), S.detach().numpy()[0]
# Endmembers normalization
for i in range(A.shape[1]):
        M = A[:, i].max().item()
        A[:, i] = A[:, i]/M
                      
print('compare_endmembers', compare_endmembers(urban, A))
plt.figure(figsize=(8,6))
for ii in range(6): 
    ax = plt.subplot(2, 3, ii+1)
    ax.plot(A[:,ii])
plt.show()
                
print('compare_abundances', compare_abundances(urban, S))
plt.figure(figsize=(8,6))
for ii in range(6): 
    ax = plt.subplot(2, 3, ii+1)
    ax.imshow(S[ii, :, :])  
plt.show()
